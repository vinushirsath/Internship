# %% [markdown]
# # Problem Statement:
# E-retail factors for customer activation and retention: A case study from Indian e-commerce customers
#
# Customer satisfaction has emerged as one of the most important factors that guarantee the success of online store; it has been posited as a key stimulant of purchase, repurchase intentions and customer loyalty. A comprehensive review of the literature, theories and models have been carried out to propose the models for customer activation and customer retention. Five major factors that contributed to the success of an e-commerce store have been identified as: service quality, system quality, information quality, trust and net benefit. The research furthermore investigated the factors that influence the online customers repeat purchase intention. The combination of both utilitarian value and hedonistic values are needed to affect the
# repeat purchase intention (loyalty) positively. The data is collected from the Indian online shoppers. Results indicate the e-retail success factors, which are very much critical for customer satisfaction.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt


import warnings
warnings.filterwarnings("ignore")

# %%
data=pd.read_excel("customer_retention_dataset 1.xlsx")
data.head()
# Out:
#   1Gender of respondent 2 How old are you?   \
# 0                  Male         31-40 years
# 1                Female         21-30 years
# 2                Female         21-30 years
# 3                  Male         21-30 years
# 4                Female         21-30 years
#
#   3 Which city do you shop online from?  \
# 0                                 Delhi
# 1                                 Delhi
# 2                         Greater Noida
# 3                               Karnal
# 4                            Bangalore
#
#    4 What is the Pin Code of where you shop online from?  \
# 0                                             110009
# 1                                             110030
# 2                                             201308
# 3                                             132001
# 4                                             530068
#
#   5 Since How Long You are Shopping Online ?  \
# 0                              Above 4 years
# ...

# %%
data.shape
# Out:
# (269, 71)

# %%
data.isna().sum().sum()
# Out:
# 0

# %%
from string import digits

#Removing tab spaces
data.columns = data.columns.str.replace('\t','')

#Removing digits
remove_digits = str.maketrans('', '', digits)
data.columns = data.columns.str.translate(remove_digits)

#Removing leading and trailling spaces
data.columns = data.columns.str.strip()

# %%
data.head()
# Out:
#   Gender of respondent How old are you? Which city do you shop online from?  \
# 0                 Male      31-40 years                               Delhi
# 1               Female      21-30 years                               Delhi
# 2               Female      21-30 years                       Greater Noida
# 3                 Male      21-30 years                             Karnal
# 4               Female      21-30 years                          Bangalore
#
#    What is the Pin Code of where you shop online from?  \
# 0                                             110009
# 1                                             110030
# 2                                             201308
# 3                                             132001
# 4                                             530068
#
#   Since How Long You are Shopping Online ?  \
# 0                            Above 4 years
# 1                            Above 4 years
# 2                                3-4 years
# ...

# %%
#Finding the niull values

data.isna().sum().sum()
# Out:
# 0

# %%
#It is observed that no null vaiues are present in dataset

# %%
#Finding the descriptions of column
data.columns
# Out:
# Index(['Gender of respondent', 'How old are you?',
#        'Which city do you shop online from?',
#        'What is the Pin Code of where you shop online from?',
#        'Since How Long You are Shopping Online ?',
#        'How many times you have made an online purchase in the past  year?',
#        'How do you access the internet while shopping on-line?',
#        'Which device do you use to access the online shopping?',
#        'What is the screen size of your mobile device?',
#        'What is the operating system (OS) of your device?',
#        'What browser do you run on your device to access the website?',
#        'Which channel did you follow to arrive at your favorite online store for the first time?',
#        'After first visit, how do you reach the online retail store?',
#        'How much time do you explore the e- retail store before making a purchase decision?',
#        'What is your preferred payment Option?',
# ...

# %% [markdown]
# # Basic Information about customers

# %%
personal_info=['Gender of respondent', 'How old are you?',
       'Which city do you shop online from?',
       'What is the Pin Code of where you shop online from?',
       'Since How Long You are Shopping Online ?',
       'How many times you have made an online purchase in the past  year?']

# %%
for i in personal_info:
    if i!='What is the Pin Code of where you shop online from?':
        plt.figure(figsize=(8,6))
        data[i].value_counts().plot.pie(autopct='%1.1f%%')
        plt.xlabel(i)
        plt.ylabel("")
        plt.figure()

# %%
#From above it is observed that female customers percentage is 67.3% where as only 33.7% males are buying online.
#Age group 31-40 years are having highest customers:-30.1% followed by age group 21-30 years :29.4% & age group 41-50 years:-26%.
#It observed that less than 20 years teenagers & above 51 years are very less no. of customers.
#It observed that delhi is having highest customers :21% but considering noida & greater noidaalso large no. of customers as compared to delhi if we club both the regions in one.
#Followed by Bangalore is alos having good nos. of online customers :-13.8%.
#Bulandshahar is having very less no. of customers :0.7%, followed by Moradabad:1.9%, Merut:3.3% & Grugaon:-4.5% as seen they are not much aware about online shoppings.
#Around 36% peoples are shopping online from more than 4 years, 24% peoplease are shopping online from 2-3 years, 17% peoples are 3-4 years.
#16% peoplease are shopping online less than 1 year & vey less 5.9% peoples are shopping 1-2 years.
#Less than 10 times 42% peoples are shopping online in past year. Followed by 31-40 times around 23% peoples are shopped online.
#Only 2.2% peoples 42 times & above are shpped online followed by 3.7% peoples who areshopped 21-30 times.

# %%
#Lest plot the genderwise graph Vs. Age group
sns.countplot(data['Gender of respondent'], hue=data['How old are you?'])
# Out:
# <AxesSubplot:xlabel='Gender of respondent', ylabel='count'>

# %%
#In male online customers, age group 31- 40 years highest nos. of customers. Follwed by age group 41- 50 yeras & age group 21-30.Age group less than 20 years & more than 51 years are very less customers.

#In female customers, Age group 21-30 years having higher contribution in online purchasing, followed by age group 31-40 years & Age group 41-50 years. 

#Very less no. of customers of age group less than 20 years & more than 51 years in both male & female both.

# %% [markdown]
# # Finding location wise E retail customers

# %%
plt.figure(figsize=(10,8))
sns.countplot(data['Which city do you shop online from?'],hue=data['Gender of respondent'])
plt.show()

# %%
# In Delhi & Noida cities male customers are higher than female customers.
#Whereas other cities like greater noida, Bangalore, karnal, solan , Gaziabad female customers are higher than male customers.

# %% [markdown]
# # Finding Device used data & accessing web info

# %%
Device_info=['How do you access the internet while shopping on-line?',
       'Which device do you use to access the online shopping?',
       'What is the screen size of your mobile device?',
       'What is the operating system (OS) of your device?']

# %%
for i in Device_info:
    plt.figure(figsize=(8,6))
    data[i].value_counts().plot.pie(autopct='%1.1f%%')
    plt.xlabel(i)
    plt.ylabel("")
    plt.figure()

# %%
# From above data it is observed that most of peoplee are using smartphones:52 % for online purchasing.Followed by laptops:32%, Desktops:-11 % & only 4.5% peoples are using tablets.
#Smartphones are popularly used for online purchasing & tablets are not used by peoples.
#52% peoples are using mobile internet as lot of peoples are using smartphones for online purchasing.28% peoples using wifi, 17% peoples are by mobile internet.Only 1.5% peoples are using dial up connection.
#36 % peoples mobile phone scren size is .5 inches, whereas 10.8% peoples phone size is 4.7 inches. Aound 49% peoples phone screen size in not defined.
#Mojority of peoples are using window/windows OS around 45%.Whereas 31.6% peoples are using adroid OS & 23% peoples are using IOS/MAc.

# %% [markdown]
# # Finding which browser used for browsing

# %%
browser=['What browser do you run on your device to access the website?',
       'Which channel did you follow to arrive at your favorite online store for the first time?',
       'After first visit, how do you reach the online retail store?',
       'How much time do you explore the e- retail store before making a purchase decision?',
       'What is your preferred payment Option?']

# %%
for i in browser:
    plt.figure(figsize=(8,6))
    data[i].value_counts().plot.pie(autopct='%1.1f%%')
    plt.xlabel(i)
    plt.ylabel("")
    plt.figure()

# %%
#Google chrome is polpularly used for browsing 80%. Whereas other browsers are not used like mozill firefox:1.9%, Opera:3%, Safari:-14%.
#For first time people generally used search engine :85.5%. Only few peoplease using content marketing, dispay advert.
#32.3% Peoples reach to online retail store by search engine after first visit, folowed by 32% peoples via application, 26% peoples via URL, 6.7% peoples by E mail & 3 % people by social media.
#More than 15 mins:-45.7% peoples are explore e retail store before making puchase decisions.24% peoples explore 6-10 min, 17% peoles 10-15 mins.
#Generally 55% peoples are using credit/debit card, 28% peoples using cash on delivery & 16% peoples are using E wallets(Paytm, frechardge) for making payment.

# %%
#Checking why customers are abondon the Bag & shpping cart
Cart=['How frequently do you abandon (selecting an items and leaving without making payment) your shopping cart?',
       'Why did you abandon the “Bag”, “Shopping Cart”?']

# %%
for i in Cart:
    plt.figure(figsize=(8,6))
    data[i].value_counts().plot.pie(autopct='%1.1f%%')
    plt.xlabel(i)
    plt.ylabel("")
    plt.figure()

# %%
#63.7% peoples sometimes are abandon the shopping cart without making payment, 17.7% peoples are never abandon the shopping cart, 5.6%peoples are very frequesntly abandon the cart, 13% frequently.
#They abndon because 49.4% peoples got better alternative affer, 20.1% people leaves due to Promo code not applicable, 13.8% leaves due to change in price, 11.5% leave due to lack of trust on item, 5.2% due to no preferrened mode of payment.

# %% [markdown]
# # Product information

# %%
Product_information=['The content on the website must be easy to read and understand',
       'Information on similar product to the one highlighted  is important for product comparison',
       'Complete information on listed seller and product being offered is important for purchase decision.',
       'All relevant information on listed products must be stated clearly']

# %%
for i in Product_information:
    plt.figure(figsize=(8,6))
    data[i].value_counts().plot.pie(autopct='%1.1f%%')
    plt.xlabel(i)
    plt.ylabel("")
    plt.figure()

# %%
#61% peoples are strongly agreed that content of website must be easy to read & understand.29% are agreed
#Most of peoples are strongly agreed & agrred that:-The content on the website must be easy to read and understand,
#Information on similar product to the one highlighted  is important for product comparison',
#Complete information on listed seller and product being offered is important for purchase decision.',
#All relevant information on listed products must be stated clearly.

#Very less no. of peoples are disagreed.

# %% [markdown]
# # System Quality

# %%
Web=['Ease of navigation in website', 'Loading and processing speed',
       'User friendly Interface of the website', 'Convenient Payment methods',
       'Trust that the online retail store will fulfill its part of the transaction at the stipulated time']

# %%
for i in Web:
    plt.figure(figsize=(8,6))
    data[i].value_counts().plot.pie(autopct='%1.1f%%')
    plt.xlabel(i)
    plt.ylabel("")
    plt.figure()

# %%
#Most of peoples are strongly agreed & satisfy with Ease of navigation in website', 'Loading and processing speed',
#'User friendly Interface of the website', 'Convenient Payment methods',
#'Trust that the online retail store will fulfill its part of the transaction at the stipulated time']

# %% [markdown]
# # Service Quality

# %%
Customer_Satisfaction=['Empathy (readiness to assist with queries) towards the customers',
       'Being able to guarantee the privacy of the customer',
       'Responsiveness, availability of several communication channels (email, online rep, twitter, phone etc.)',
       'Online shopping gives monetary benefit and discounts',
       'Enjoyment is derived from shopping online',
       'Shopping online is convenient and flexible',
       'Return and replacement policy of the e-tailer is important for purchase decision',
       'Gaining access to loyalty programs is a benefit of shopping online',
       'Displaying quality Information on the website improves satisfaction of customers',
       'User derive satisfaction while shopping on a good quality website or application',
       'Net Benefit derived from shopping online can lead to users satisfaction',
       'User satisfaction cannot exist without trust']

# %%
for i in Customer_Satisfaction:
    plt.figure(figsize=(8,6))
    data[i].value_counts().plot.pie(autopct='%1.1f%%')
    plt.xlabel(i)
    plt.ylabel("")
    plt.figure()

# %%
#Most of the peoples are strongly agreed & agreed that the E retail must follow points:
#        'Empathy (readiness to assist with queries) towards the customers',
#       'Being able to guarantee the privacy of the customer',
#       'Responsiveness, availability of several communication channels (email, online rep, twitter, phone etc.)',
#       'Online shopping gives monetary benefit and discounts',
#       'Enjoyment is derived from shopping online',
#       'Shopping online is convenient and flexible',
#       'Return and replacement policy of the e-tailer is important for purchase decision',
#       'Gaining access to loyalty programs is a benefit of shopping online',
#       'Displaying quality Information on the website improves satisfaction of customers',
#       'User derive satisfaction while shopping on a good quality website or application',
#       'Net Benefit derived from shopping online can lead to users satisfaction',
#       'User satisfaction cannot exist without trust']

# %% [markdown]
# # Net Benifits

# %%
Customer_delightness=['Offering a wide variety of listed product in several category',
       'Provision of complete and relevant product information',
       'Monetary savings',
       'The Convenience of patronizing the online retailer',
       'Shopping on the website gives you the sense of adventure',
       'Shopping on your preferred e-tailer enhances your social status',
       'You feel gratification shopping on your favorite e-tailer',
       'Shopping on the website helps you fulfill certain roles',
       'Getting value for money spent']

# %%
for i in Customer_delightness:
    plt.figure(figsize=(8,6))
    data[i].value_counts().plot.pie(autopct='%1.1f%%')
    plt.xlabel(i)
    plt.ylabel("")
    plt.figure()

# %% [markdown]
# # Brand_image

# %%
Brand_image=['From the following, tick any (or all) of the online retailers you have shopped from;',
       'Easy to use website or application',
       'Visual appealing web-page layout', 'Wild variety of product on offer',
       'Complete, relevant description information of products',
       'Fast loading website speed of website and application',
       'Reliability of the website or application',
       'Quickness to complete purchase',
       'Availability of several payment options', 'Speedy order delivery',
       'Privacy of customers’ information',
       'Security of customer financial information',
       'Perceived Trustworthiness',
       'Presence of online assistance through multi-channel',
       'Longer time to get logged in (promotion, sales period)',
       'Longer time in displaying graphics and photos (promotion, sales period)',
       'Late declaration of price (promotion, sales period)',
       'Longer page loading time (promotion, sales period)',
       'Limited mode of payment on most products (promotion, sales period)',
       'Longer delivery period', 'Change in website/Application design',
       'Frequent disruption when moving from one page to another',
       'Website is as efficient as before']

# %%
for i in Brand_image:
    plt.figure(figsize=(20,5))
    sns.countplot(data[i],hue=data['Which of the Indian online retailer would you recommend to a friend?'])
    plt.xlabel(i)
    plt.ylabel("")
    plt.xticks(rotation=45)
    plt.show()

# %%
#As per above data it is clear that Amazon & Flipcart having very good brand image as considering following points:
#        Easy to use website or application',
#       'Visual appealing web-page layout', 'Wild variety of product on offer',
#       'Complete, relevant description information of products',
#       'Fast loading website speed of website and application',
#       'Reliability of the website or application',
#       'Quickness to complete purchase',
#       'Availability of several payment options', 'Speedy order delivery',
#       'Privacy of customers’ information',
#       'Security of customer financial information',
#       'Perceived Trustworthiness',
#       'Presence of online assistance through multi-channel',
#       'Longer time to get logged in (promotion, sales period)',
#       'Longer time in displaying graphics and photos (promotion, sales period)',
#       'Late declaration of price (promotion, sales period)',
#       'Longer page loading time (promotion, sales period)',
#       'Limited mode of payment on most products (promotion, sales period)',
#       'Longer delivery period', 'Change in website/Application design',
#       'Frequent disruption when moving from one page to another',
#       'Website is as efficient as before'

# %%
#Finding the correlation between first time peoples arrived Vs Second visit
plt.figure(figsize=(10,10))
sns.countplot(data['12 Which channel did you follow to arrive at your favorite online store for the first time?                                                                   '],hue=data['13 After first visit, how do you reach the online retail store?\t\t\t\t                                                   '])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '12 Which channel did you follow to arrive at your favorite online store for the first time?                                                                   '
#
# ...

# %%
# Via Search engine peoples are arrive at online store.
#But after first visit people also use search engine to reached at online store. Followed by most of peoples uses application to reach online store.
#Some peoples are lso uses url to reachat online store.

# %%
plt.figure(figsize=(15,5))
sns.countplot(data['Which of the Indian online retailer would you recommend to a friend?'])
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # Conclusion

# %%
#From all above data it is observed that Female E retail customers are higher nos. as compared to male customers.
#Delhi is having large no. of customers followed by Greater Noida & Noida, Bangalore.
#21-30 Years age group having highest no. of female customers followed by 31-40 years.
#Teen ager group less than 20 years & above 51 years in both male & female are having very less no. of customers.
#Please are generally using mobile internet to access website from smartphones which is maximum having 5.5 inches screen & using Android Operating system.
#Peoples are using search engine Google chrome to reach favourite E retail store first time & 32% peoples are using Application & 32% people using search engine for second time visit.
#Sometime around 67% peoples abandon the item in cart due o better alternative offer, Promo code is not applicable & Change in price.
#Most of peoples are strongly agreed & agreed in favour that the content on the website must be easy to read & understand, information on similar product to the one highlighted is important for product comparison, complete product is important for purchase decision & all relevant information on listed products must be stated clearly.
#Most of peoples are strongly agreed that E retail store must be taking care the privacy of customer details, bet benefit, resolve  customer problem, return & replacement quickly, product information & details must be properly mentioned on the web.
#Amazon & Flipcart is having very good brand image as compared to other E retail shop considering the verity of products, quick delivery, customer satisfaction, easy return & replacement policy, payment security, customer details privacy 'Complete, relevant description information of products, Fast loading website speed of website and application, Reliability of the website or application, Quickness to complete purchase, Availability of several payment options, Speedy order delivery, Perceived Trustworthiness, Presence of online assistance through multi-channel,
