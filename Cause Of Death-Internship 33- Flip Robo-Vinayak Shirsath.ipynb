# %% [markdown]
# # About Dataset
# Context
# A straightforward way to assess the health status of a population is to focus on mortality – or concepts like child mortality or life expectancy, which are based on mortality estimates. A focus on mortality, however, does not take into account that the burden of diseases is not only that they kill people, but that they cause suffering to people who live with them. Assessing health outcomes by both mortality and morbidity (the prevalent diseases) provides a more encompassing view on health outcomes. This is the topic of this entry. The sum of mortality and morbidity is referred to as the ‘burden of disease’ and can be measured by a metric called ‘Disability Adjusted Life Years‘ (DALYs). DALYs are measuring lost health and are a standardized metric that allow for direct comparisons of disease burdens of different diseases across countries, between different populations, and over time. Conceptually, one DALY is the equivalent of losing one year in good health because of either premature death or disease or disability. One DALY represents one lost year of healthy life. The first ‘Global Burden of Disease’ (GBD) was GBD 1990 and the DALY metric was prominently featured in the World Bank’s 1993 World Development Report. Today it is published by both the researchers at the Institute of Health Metrics and Evaluation (IHME) and the ‘Disease Burden Unit’ at the World Health Organization (WHO), which was created in 1998. The IHME continues the work that was started in the early 1990s and publishes the Global Burden of Disease study.
# Content
# In this Dataset, we have Historical Data of different cause of deaths for all ages around the World. The key features of this Dataset are: Meningitis, Alzheimer's Disease and Other Dementias, Parkinson's Disease, Nutritional Deficiencies, Malaria, Drowning, Interpersonal Violence, Maternal Disorders, HIV/AIDS, Drug Use Disorders, Tuberculosis, Cardiovascular Diseases, Lower Respiratory Infections, Neonatal Disorders, Alcohol Use Disorders, Self-harm, Exposure to Forces of Nature, Diarrheal Diseases, Environmental Heat and Cold Exposure, Neoplasms, Conflict and Terrorism, Diabetes Mellitus, Chronic Kidney Disease, Poisonings, Protein-Energy Malnutrition, Road Injuries, Chronic Respiratory Diseases, Cirrhosis and Other Chronic Liver Diseases, Digestive Diseases, Fire, Heat, and Hot Substances, Acute Hepatitis.
# Dataset Glossary (Column-wise)
# •	01. Country/Territory - Name of the Country/Territory
# •	02. Code - Country/Territory Code
# •	03. Year - Year of the Incident
# •	04. Meningitis - No. of People died from Meningitis
# •	05. Alzheimer's Disease and Other Dementias - No. of People died from Alzheimer's Disease and Other Dementias
# •	06. Parkinson's Disease - No. of People died from Parkinson's Disease
# •	07. Nutritional Deficiencies - No. of People died from Nutritional Deficiencies
# •	08. Malaria - No. of People died from Malaria
# •	09. Drowning - No. of People died from Drowning
# •	10. Interpersonal Violence - No. of People died from Interpersonal Violence
# •	11. Maternal Disorders - No. of People died from Maternal Disorders
# •	12. Drug Use Disorders - No. of People died from Drug Use Disorders
# •	13. Tuberculosis - No. of People died from Tuberculosis
# •	14. Cardiovascular Diseases - No. of People died from Cardiovascular Diseases
# •	15. Lower Respiratory Infections - No. of People died from Lower Respiratory Infections
# •	16. Neonatal Disorders - No. of People died from Neonatal Disorders
# •	17. Alcohol Use Disorders - No. of People died from Alcohol Use Disorders
# •	18. Self-harm - No. of People died from Self-harm
# •	19. Exposure to Forces of Nature - No. of People died from Exposure to Forces of Nature
# •	20. Diarrheal Diseases - No. of People died from Diarrheal Diseases
# •	21. Environmental Heat and Cold Exposure - No. of People died from Environmental Heat and Cold Exposure
# •	22. Neoplasms - No. of People died from Neoplasms
# •	23. Conflict and Terrorism - No. of People died from Conflict and Terrorism
# •	24. Diabetes Mellitus - No. of People died from Diabetes Mellitus
# •	25. Chronic Kidney Disease - No. of People died from Chronic Kidney Disease
# •	26. Poisonings - No. of People died from Poisoning
# •	27. Protein-Energy Malnutrition - No. of People died from Protein-Energy Malnutrition
# •	28. Chronic Respiratory Diseases - No. of People died from Chronic Respiratory Diseases
# •	29. Cirrhosis and Other Chronic Liver Diseases - No. of People died from Cirrhosis and Other Chronic Liver Diseases
# •	30. Digestive Diseases - No. of People died from Digestive Diseases
# •	31. Fire, Heat, and Hot Substances - No. of People died from Fire or Heat or any Hot Substances
# •	32. Acute Hepatitis - No. of People died from Acute Hepatitis
#
# Steps to Follow
# https://www.kaggle.com/code/spscientist/a-simple-tutorial-on-exploratory-data-analysis
# https://en.wikipedia.org/wiki/Exploratory_data_analysis#:~:text=In%20statistics%2C%20exploratory%20data%20analysis,and%20other%20data%20visualization%20methods.
#
# Note : Data Scientists have to apply their analytical skills to give findings and conclusions in detailed data analysis written in jupyter notebook . Only data analysis is required.
# Need not to create machine learning models /but still if anybody comes with it that is welcome.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

import warnings
warnings.filterwarnings("ignore")

# %%
df=pd.read_csv("cause_of_deaths dataset.csv")
df.head(5)
# Out:
#   Country/Territory Code  Year  Meningitis  \
# 0       Afghanistan  AFG  1990        2159
# 1       Afghanistan  AFG  1991        2218
# 2       Afghanistan  AFG  1992        2475
# 3       Afghanistan  AFG  1993        2812
# 4       Afghanistan  AFG  1994        3027
#
#    Alzheimer's Disease and Other Dementias  Parkinson's Disease  \
# 0                                     1116                  371
# 1                                     1136                  374
# 2                                     1162                  378
# 3                                     1187                  384
# 4                                     1211                  391
#
#    Nutritional Deficiencies  Malaria  Drowning  Interpersonal Violence  ...  \
# 0                      2087       93      1370                    1538  ...
# 1                      2153      189      1391                    2001  ...
# 2                      2441      239      1514                    2299  ...
# ...

# %%
#Above dataset is of finding the cause of death from variouse deceases.Data is collected from different countries.

# %%
#Finding the shape
df.shape
# Out:
# (6120, 34)

# %%
#It has 6120 rows & 34 columns.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6120 entries, 0 to 6119
# Data columns (total 34 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   Country/Territory                           6120 non-null   object
#  1   Code                                        6120 non-null   object
#  2   Year                                        6120 non-null   int64
#  3   Meningitis                                  6120 non-null   int64
#  4   Alzheimer's Disease and Other Dementias     6120 non-null   int64
#  5   Parkinson's Disease                         6120 non-null   int64
#  6   Nutritional Deficiencies                    6120 non-null   int64
#  7   Malaria                                     6120 non-null   int64
#  8   Drowning                                    6120 non-null   int64
#  9   Interpersonal Violence                      6120 non-null   int64
# ...

# %%
#Country code & code are object datatype, remaining are the interger datatype

# %%
#Finding the duplicate values
df.duplicated().sum()
# Out:
# 0

# %%
#No duplicate values are present

# %%
#Finding the null values
df.isna().sum()
# Out:
# Country/Territory                             0
# Code                                          0
# Year                                          0
# Meningitis                                    0
# Alzheimer's Disease and Other Dementias       0
# Parkinson's Disease                           0
# Nutritional Deficiencies                      0
# Malaria                                       0
# Drowning                                      0
# Interpersonal Violence                        0
# Maternal Disorders                            0
# HIV/AIDS                                      0
# Drug Use Disorders                            0
# Tuberculosis                                  0
# Cardiovascular Diseases                       0
# Lower Respiratory Infections                  0
# Neonatal Disorders                            0
# Alcohol Use Disorders                         0
# Self-harm                                     0
# Exposure to Forces of Nature                  0
# ...

# %%
#No null values are present in data

# %%
df.describe()
# Out:
#               Year    Meningitis  Alzheimer's Disease and Other Dementias  \
# count  6120.000000   6120.000000                              6120.000000
# mean   2004.500000   1719.701307                              4864.189379
# std       8.656149   6672.006930                             18220.659072
# min    1990.000000      0.000000                                 0.000000
# 25%    1997.000000     15.000000                                90.000000
# 50%    2004.500000    109.000000                               666.500000
# 75%    2012.000000    847.250000                              2456.250000
# max    2019.000000  98358.000000                            320715.000000
#
#        Parkinson's Disease  Nutritional Deficiencies        Malaria  \
# count          6120.000000               6120.000000    6120.000000
# mean           1173.169118               2253.600000    4140.960131
# std            4616.156238              10483.633601   18427.753137
# ...

# %%
#data columns are very big in nos. hence plotting graph in order visualise more no. of columns

# %% [markdown]
# # EDA

# %%
df1=df.drop(columns=["Country/Territory","Code"],axis=1)
df1.head()
# Out:
#    Year  Meningitis  Alzheimer's Disease and Other Dementias  \
# 0  1990        2159                                     1116
# 1  1991        2218                                     1136
# 2  1992        2475                                     1162
# 3  1993        2812                                     1187
# 4  1994        3027                                     1211
#
#    Parkinson's Disease  Nutritional Deficiencies  Malaria  Drowning  \
# 0                  371                      2087       93      1370
# 1                  374                      2153      189      1391
# 2                  378                      2441      239      1514
# 3                  384                      2837      108      1687
# 4                  391                      3081      211      1809
#
#    Interpersonal Violence  Maternal Disorders  HIV/AIDS  ...  \
# 0                    1538                2655        34  ...
# 1                    2001                2885        41  ...
# ...

# %%
plt.figure(figsize=(20,25))
plotnumber=1


for column in df1:
    if plotnumber<=32:
        ax=plt.subplot(8,4, plotnumber)
        sns.distplot(df[column])
        plt.xlabel(column,fontsize=20)
    plotnumber+=1
    
plt.tight_layout()

# %%
df["Year"].value_counts()
# Out:
# 1990    204
# 1991    204
# 2018    204
# 2017    204
# 2016    204
# 2015    204
# 2014    204
# 2013    204
# 2012    204
# 2011    204
# 2010    204
# 2009    204
# 2008    204
# 2007    204
# 2006    204
# 2005    204
# 2004    204
# 2003    204
# 2002    204
# 2001    204
# 2000    204
# 1999    204
# 1998    204
# 1997    204
# 1996    204
# 1995    204
# 1994    204
# 1993    204
# 1992    204
# 2019    204
# Name: Year, dtype: int64

# %%
#From above it is observed that it equal no. of yearwise data has been collected.

# %%
#Lets isualise the countrywise death count
df["Country/Territory"].value_counts().sum()
# Out:
# 6120

# %%
#Each country having 30 nos. of data has been collected

# %%
diseases=['Meningitis',
       "Alzheimer's Disease and Other Dementias", "Parkinson's Disease",
       'Nutritional Deficiencies', 'Malaria', 'Drowning',
       'Interpersonal Violence', 'Maternal Disorders', 'HIV/AIDS',
       'Drug Use Disorders', 'Tuberculosis', 'Cardiovascular Diseases',
       'Lower Respiratory Infections', 'Neonatal Disorders',
       'Alcohol Use Disorders', 'Self-harm', 'Exposure to Forces of Nature',
       'Diarrheal Diseases', 'Environmental Heat and Cold Exposure',
       'Neoplasms', 'Conflict and Terrorism', 'Diabetes Mellitus',
       'Chronic Kidney Disease', 'Poisonings', 'Protein-Energy Malnutrition',
       'Road Injuries', 'Chronic Respiratory Diseases',
       'Cirrhosis and Other Chronic Liver Diseases', 'Digestive Diseases',
       'Fire, Heat, and Hot Substances', 'Acute Hepatitis']

# %%
#plotting Disease Vs Year Graph

plt.figure(figsize=(20,200))
plotnumber=1

for i in diseases:
    if plotnumber<=32:
        ax=plt.subplot(31,1,plotnumber)
        sns.barplot(y=df[i], x=df["Year"], ci=None)
        plt.xlabel("Year")
    plotnumber+=1
    
plt.show()

# %% [raw]
# -Looking at the column Meningitis the year wise death trend is decreasing.
# -Alzheimers are increasing in trend.Need to take some action to control  this dicease.
# -Parkinsons disease are alos increasing in trend.
# -Nutritional deficiancies are also decreasing trend but in 1995 it is increased & after 1995 it follows decreasing trend.
# -Maleria is also decreasing in trend but in the span of 2002 to 2010 it is consistent in nature. After 2010 it is in control & having decreasing trend.
# -Drowing-deaths are also follows decrease trend. In 1990 it is at the peak but in 2019 it bring down.
# -Interpersonal Violence- deaths is having slitely increasing & consistent trend.
# -Maternal disorder deaths are also having decreaing in trend.
# -HIV/AIDS deaths : in 1990 it is having less no. of deaths but from 1990 it is increasing in trend up to 2004/2005 & afterthat the trend is down.
# -Drug use disorder: Having increasing in trend. In the year of 2001 to 2008 it decreased & consistent & after 2008 it is increasing in nature.
# -Tuberculosis deaths are reduced from 1990 too 2019.
# -Cardiovascular disease deaths are increasing in nature from 1990 to 2019.
# -Lower respiratory infection deths are reducing in trend but consistent in nature. fro 2010 to 2019 it is consistent deaths are recorded.
# -Neonatal disorder deaths are reduced from 1990 to 2019.
# -Alcohol use disorder is less in 1990 but afterthat it is increasing in nature. In 2001 to 2006 it is high but after 2006 it is reducing in nature. In 2019 it is slitely increased.
# -Self harm deaths are consistent.
# -Exposure to forces of nature deaths:In the year of 1991, 2004, 2008 & 2010 it is increased but in other years no significant major no. of death are recorded.
# -Diarrheal disease deaths are reducing in nature.
# -Environmental heat and cold exposure deaths: In 1993 to 1996 & 2004 to 2006 maximum no. deaths are recorded. Some variations are observed but trend in reducing in nature.
# -Deaths due to neaoplasms are increasing in nature.
# -Conflit& terrerism deaths: in 1994 huge nos. of deaths are reported, after that from 2014 to 2016 major nos. of deaths are reported.
# -Diabetis Mellitus: The death trend in increasing in nature from 1990 to 2019.
# -Cronic kidney disease is also increase in nature from 1990 to 2019.
# -Poisoningsdeaths trend is slitely decreased but almost equal form 1990 to 2019.
# -Death due to protein energy malnutrition: from 1990 deaths are reducing but in year 1995 cases are suddenly incraeses & after 1995 it is decreasing in trend till 2019.
# -Road injuries are increases from 1990 to 2019.
# -Cronic respiratory disease are increased from 1990 to 2019.
# -Cirrhosis & other chronic liver disease are increasing in nature till 2019.
# -Digestive disease are increase in trend.
# -Fire, heat and hot substances cases are slitely decreases.
# -Accute hepititis deaths are decreaes from 1990 to 2019.

# %% [markdown]
# # Now we will find out the top countrywise disease data

# %%
diseases=df.drop(columns=["Country/Territory","Code","Year"],axis=1)
for x in diseases:
    if df[x].dtypes != 'string':
        #print(x)
        data = df.groupby(['Country/Territory'])[x].sum().sort_values(ascending =False)[:10]
        plt.figure(figsize=(9,6))
        plt.bar(data=data ,x = data.index , height = data.values, width=0.9, color = ['crimson','blue','green', 'yellow', 'magenta'])
        plt.xticks(rotation='vertical')
        plt.xlabel("COUNTRIES" , size = 10)
        plt.ylabel(x.upper()+' DEATHS PER MILLION')
        plt.title("COUNTRIES WITH HIGHEST "+x.upper()+' DEATHS')

# %% [raw]
# --Meningitis desease deaths are higher in India,Followed by Nigeria, pakistan, Ethopia & China they are top five most contributer
# -Alzheimers desease deaths are higher in china, US, Japan, India & Germany. They ae the top five major contributer.
# -Parkinsons : Highest no. of deaths in China, India, US Japan & Germany.
# -Nutritional deficiancey desease:- India is at highest, followed by Ethiopia, Bangadesh, North corea & indonetia.
# -Maleria deaths:-Nigeria is at highest for deaths due to maleria followed by democretic republic of congo, Inda, Uganda & Barkina faso.
# -Drowning deaths: Cina is at highest for deaths due to drowning followed by India, Bangladesh, Russia & Brasil.
# -Interpersonal violence deaths:- Brasil is at highest for inter personal deaths, followed by India, Russia, China & Colombia.
# -Maternal disorder deaths: Highest is India, followed by Nigeria, Pakistan, Indonetia & Ethiopia.
# -HIV/Aids Deaths: South Africa at highest, followed by Kenya, Tanzania, India & Nigeria.
# -Drug used disorder deaths:- US is at top, followed by china, Russia, India & Iran.
# -Tuberculosis Deaths:-India is at the high, follwed by Indonetia, China, Pakistan &  Nigeria.
# -Cardiovascular disease deaths:-China is having hieghest deaths, followed by India,Russia, US & Indonetia.
# -Lower respiratory infection deaths:-India is at highest, followed by china, Nigeia, Japan & Pakistan.
# -Neonathal disorder deaths: India is at highest, followed by pakistan, nigeria, china & ethiopai.
# -Alcohol use disoder deaths : Russians at highest followed by India, China, US & ukrain.
# -Self Harm deaths: India is at high, followed by china, russia, US & Japan.
# -Expouser to forces of natural deaths: Haiti is at highest for deaths followed by indonetia, bangladesh, Myanmar & china.
# -Diarrheal disease:India is highest deaths, followd by Nigerai, pakistan, indonetia & Ethiopia.
# Environmental heat & cold exposure deaths:Russia, India & china are the highest, folowed by Ukrain & japan.
# -Neoplasms deaths:Chian is highest, followed by US, India, Japan & russia.
# -Conflict & terrorism deaths:-Rawnda is at highest follwed by Syria, Iraq, Afghanistan & Burundi.
# -Diabetes mellitus deaths: India is at highest, followed by china, US, Indonetia & maxico.
# -Chronic kidney disease:India, china, US, maxico & japan are highest in kidney disease deaths.
# -Poisoning deaths:China is at highest, followed by russia, india, nigeria & Ethiopia.
# -Protein energy malnutrition deaths:- India is at highest for these deaths, followed by Ethiopia, North corea, bangladesh & indonetia.
# -Road Injuries deaths:-China is at the top, followed by India, US, Brazil & indonetia.
# -Chronic respiratory disease deaths:-China , India, US, Indonesia & pakistan are the top five.
# -Cirrhosis & other chronic disease deaths:India, china, indonesia, US & Egypt are the top fiv.
# -Digestive disease deaths:India is at the top, follwed by china, indonesia, US & russia.
# -Fire, Heat & hot substances:-India is a the top, follwed by china, russia, us & Nigeria.
# -Accute hepatitis deaths:India is at thetop, followed by china, pakistan, indonesia & bangladesh.

# %% [raw]
# -From above it is observed that most of the deaths due to abive disease happened in India, China, US, Russia & pakistan.

# %%
df.columns
# Out:
# Index(['Country/Territory', 'Code', 'Year', 'Meningitis',
#        'Alzheimer's Disease and Other Dementias', 'Parkinson's Disease',
#        'Nutritional Deficiencies', 'Malaria', 'Drowning',
#        'Interpersonal Violence', 'Maternal Disorders', 'HIV/AIDS',
#        'Drug Use Disorders', 'Tuberculosis', 'Cardiovascular Diseases',
#        'Lower Respiratory Infections', 'Neonatal Disorders',
#        'Alcohol Use Disorders', 'Self-harm', 'Exposure to Forces of Nature',
#        'Diarrheal Diseases', 'Environmental Heat and Cold Exposure',
#        'Neoplasms', 'Conflict and Terrorism', 'Diabetes Mellitus',
#        'Chronic Kidney Disease', 'Poisonings', 'Protein-Energy Malnutrition',
#        'Road Injuries', 'Chronic Respiratory Diseases',
#        'Cirrhosis and Other Chronic Liver Diseases', 'Digestive Diseases',
#        'Fire, Heat, and Hot Substances', 'Acute Hepatitis'],
#       dtype='object')

# %%
diseases=['Meningitis',
       "Alzheimer's Disease and Other Dementias", "Parkinson's Disease",
       'Nutritional Deficiencies', 'Malaria', 'Drowning',
       'Interpersonal Violence', 'Maternal Disorders', 'HIV/AIDS',
       'Drug Use Disorders', 'Tuberculosis', 'Cardiovascular Diseases',
       'Lower Respiratory Infections', 'Neonatal Disorders',
       'Alcohol Use Disorders', 'Self-harm', 'Exposure to Forces of Nature',
       'Diarrheal Diseases', 'Environmental Heat and Cold Exposure',
       'Neoplasms', 'Conflict and Terrorism', 'Diabetes Mellitus',
       'Chronic Kidney Disease', 'Poisonings', 'Protein-Energy Malnutrition',
       'Road Injuries', 'Chronic Respiratory Diseases',
       'Cirrhosis and Other Chronic Liver Diseases', 'Digestive Diseases',
       'Fire, Heat, and Hot Substances', 'Acute Hepatitis']

# %%
# Creating a new column for 'Total_no_of_Deaths' for individual Country and Year

df['Total_no_of_Deaths'] = df[diseases].sum(axis=1)

# %%
# Top 10 Total_no_of_Deaths

top10_Total_no_of_Deaths = df.sort_values(by='Total_no_of_Deaths',ascending=False)[:10][['Total_no_of_Deaths','Country/Territory']]

top10_Total_no_of_Deaths
# Out:
#       Total_no_of_Deaths Country/Territory
# 1139            10442561             China
# 1138            10163943             China
# 1137             9978653             China
# 1119             9814213             China
# 1118             9591222             China
# 1117             9503904             China
# 1116             9411928             China
# 1114             9366974             China
# 1115             9364587             China
# 1113             9284664             China

# %% [raw]
# From the Above table, the "top 10 - Total_no_of_Deaths" belongs to 'China'

# %%
# Total causes of death across 30 years

Countries_Total_no_of_Deaths_noyear_df = df.groupby('Country/Territory').sum()
Countries_Total_no_of_Deaths_noyear_df.drop('Year',axis=1,inplace=True)

# %% [markdown]
# # China - Top 10 Causes of Deaths

# %%
china_10 = Countries_Total_no_of_Deaths_noyear_df.sort_values(by='Total_no_of_Deaths',ascending =False)[:1]

# %%
china_10.iloc[0].sort_values(ascending=False)[1:11]
# Out:
# Cardiovascular Diseases                       100505973
# Neoplasms                                      61060527
# Chronic Respiratory Diseases                   36676826
# Digestive Diseases                              8924906
# Lower Respiratory Infections                    8525819
# Road Injuries                                   8350399
# Alzheimer's Disease and Other Dementias         5381846
# Self-harm                                       5078550
# Cirrhosis and Other Chronic Liver Diseases      4918899
# Neonatal Disorders                              4353666
# Name: China, dtype: int64

# %%
plt.figure(figsize=(8,4),dpi=200)
china_10.iloc[0].sort_values(ascending=False)[1:11].plot(kind='barh')
plt.xlabel("Total no.of Deaths")
plt.ylabel("Causes of Deaths")
plt.title("Top 10 Causes of Deaths in China")
plt.show();

# %% [markdown]
# # India - Top 10 Causes of Deaths

# %%
India_10 = Countries_Total_no_of_Deaths_noyear_df.sort_values(by='Total_no_of_Deaths',ascending =False)[1:2]

# %%
India_10.iloc[0].sort_values(ascending=False)[1:11]
# Out:
# Cardiovascular Diseases                       52994710
# Diarrheal Diseases                            26243547
# Chronic Respiratory Diseases                  25232974
# Neonatal Disorders                            20911570
# Neoplasms                                     17762703
# Lower Respiratory Infections                  16419404
# Tuberculosis                                  15820922
# Digestive Diseases                            11804380
# Cirrhosis and Other Chronic Liver Diseases     6294910
# Self-harm                                      5543395
# Name: India, dtype: int64

# %%
plt.figure(figsize=(8,4),dpi=200)
India_10.iloc[0].sort_values(ascending=False)[1:11].plot(kind='barh')
plt.xlabel("Total no.of Deaths")
plt.ylabel("Causes of Deaths")
plt.title("Top 10 Causes of Deaths in India")
plt.show();

# %% [markdown]
# # United States - Top 10 Causes of Deaths

# %%
United_States_10 = Countries_Total_no_of_Deaths_noyear_df.sort_values(by='Total_no_of_Deaths',ascending =False)[2:3]

# %%
United_States_10.iloc[0].sort_values(ascending=False)[1:11]
# Out:
# Cardiovascular Diseases                       26438346
# Neoplasms                                     18905315
# Chronic Respiratory Diseases                   4949052
# Alzheimer's Disease and Other Dementias        3302609
# Digestive Diseases                             3026943
# Lower Respiratory Infections                   2248625
# Diabetes Mellitus                              2030631
# Chronic Kidney Disease                         2018497
# Cirrhosis and Other Chronic Liver Diseases     1514325
# Road Injuries                                  1359744
# Name: United States, dtype: int64

# %%
plt.figure(figsize=(8,4),dpi=200)
United_States_10.iloc[0].sort_values(ascending=False)[1:11].plot(kind='barh')
plt.xlabel("Total no.of Deaths")
plt.ylabel("Causes of Deaths")
plt.title("Top 10 Causes of Deaths in United States")
plt.show();

# %% [markdown]
# -From above top 3 countries deaths due to disease analysis it is observed that from Cardiovacular diseases, Neoplasms, Chronic Respiratory diseases & Diarrheal disease most of the peoples died.
